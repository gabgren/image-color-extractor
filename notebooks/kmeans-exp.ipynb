# %%
from PIL import Image
import numpy as np
from sklearn.cluster import KMeans
from matplotlib import pyplot as plt

# %%
#Uncomment and Change path for image
# img=Image.open("khalisir.jpeg")
data=np.array(img).reshape((img.size[0]*img.size[1],3))

# %%
plt.imshow(img)

# %%
model=KMeans(n_clusters=5)
clusters=model.fit_predict(data)
# Out:
# c:\Users\COIMBATORE\miniconda3\envs\color_extract_kmeans\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %%
color_list=['#{:02x}{:02x}{:02x}'.format(int(i[0]),int(i[1]),int(i[2])) for i in model.cluster_centers_]
palette=np.zeros((1,5,3),dtype=np.uint8)
palette[:,:]=model.cluster_centers_

plt.xticks([0,1,2,3,4],labels=color_list)
plt.yticks([])
plt.imshow(palette)
plt.savefig("colors_pallete.png")
